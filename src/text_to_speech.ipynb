# %% [raw]
# import edge_tts
# import asyncio
# from IPython.display import Audio, display
# import io

# %% [raw]
# voice_map = {
#   "afrikaans": { "male": "af-ZA-AdriNeural", "female": "af-ZA-NaomiNeural" },
#   "amharic": { "male": "am-ET-MekdesNeural", "female": "am-ET-MekdesNeural" },
#   "arabic": { "male": "ar-SA-HamedNeural", "female": "ar-SA-ZariyahNeural" },
#   "assamese": { "male": "as-IN-DeepakNeural", "female": "as-IN-JoyatiNeural" },
#   "azerbaijani": { "male": "az-AZ-ElmirNeural", "female": "az-AZ-ZehraNeural" },
#   "bulgarian": { "male": "bg-BG-BorislavNeural", "female": "bg-BG-HristinaNeural" },
#   "bengali": { "male": "bn-BD-SaumyaNeural", "female": "bn-BD-OisheeNeural" },
#   "bosnian": { "male": "bs-BA-SamirNeural", "female": "bs-BA-SamiraNeural" },
#   "catalan": { "male": "ca-ES-AlbertNeural", "female": "ca-ES-JoanaNeural" },
#   "czech": { "male": "cs-CZ-AntoninNeural", "female": "cs-CZ-VlastaNeural" },
#   "welsh": { "male": "cy-GB-GeraintNeural", "female": "cy-GB-NiaNeural" },
#   "danish": { "male": "da-DK-ChristofferNeural", "female": "da-DK-ChristineNeural" },
#   "german": { "male": "de-DE-ConradNeural", "female": "de-DE-KatjaNeural" },
#   "greek": { "male": "el-GR-NikosNeural", "female": "el-GR-AthinaNeural" },
#   "english": { "male": "en-US-GuyNeural", "female": "en-US-JennyNeural" },
#   "spanish": { "male": "es-ES-AlvaroNeural", "female": "es-ES-ElviraNeural" },
#   "estonian": { "male": "et-EE-AadoNeural", "female": "et-EE-AnuNeural" },
#   "basque": { "male": "eu-ES-XabierNeural", "female": "eu-ES-ArantxaNeural" },
#   "persian": { "male": "fa-IR-DilaraNeural", "female": "fa-IR-DilaraNeural" },
#   "finnish": { "male": "fi-FI-HarriNeural", "female": "fi-FI-NooraNeural" },
#   "filipino": { "male": "fil-PH-JamesNeural", "female": "fil-PH-JennyNeural" },
#   "french": { "male": "fr-FR-HenriNeural", "female": "fr-FR-DeniseNeural" },
#   "irish": { "male": "ga-IE-SeanNeural", "female": "ga-IE-OrlaNeural" },
#   "galician": { "male": "gl-ES-AntonioNeural", "female": "gl-ES-AlbaNeural" },
#   "gujarati": { "male": "gu-IN-NiranjanNeural", "female": "gu-IN-DhwaniNeural" },
#   "hebrew": { "male": "he-IL-AvriNeural", "female": "he-IL-LiorNeural" },
#   "hindi": { "male": "hi-IN-AaravNeural", "female": "hi-IN-SwaraNeural" },
#   "croatian": { "male": "hr-HR-SreckoNeural", "female": "hr-HR-MajaNeural" },
#   "hungarian": { "male": "hu-HU-TamasNeural", "female": "hu-HU-NoemiNeural" },
#   "armenian": { "male": "hy-AM-AnahitNeural", "female": "hy-AM-SalpiNeural" },
#   "indonesian": { "male": "id-ID-ArdiNeural", "female": "id-ID-GadisNeural" },
#   "icelandic": { "male": "is-IS-GunnarNeural", "female": "is-IS-GudrunNeural" },
#   "italian": { "male": "it-IT-EmanueleNeural", "female": "it-IT-ValentinaNeural" },
#   "inuktitut": { "male": "iu-CA-AklarkNeural", "female": "iu-CA-AklarkNeural" },
#   "japanese": { "male": "ja-JP-KeitaNeural", "female": "ja-JP-NanamiNeural" },
#   "javanese": { "male": "jv-ID-DimasNeural", "female": "jv-ID-SitiNeural" },
#   "georgian": { "male": "ka-GE-GiorgiNeural", "female": "ka-GE-TinaNeural" },
#   "kazakh": { "male": "kk-KZ-DauletNeural", "female": "kk-KZ-DanaNeural" },
#   "khmer": { "male": "km-KH-ReyNeural", "female": "km-KH-PichNeural" },
#   "kannada": { "male": "kn-IN-MadhurNeural", "female": "kn-IN-SapnaNeural" },
#   "korean": { "male": "ko-KR-InJoonNeural", "female": "ko-KR-SunHiNeural" },
#   "lao": { "male": "lo-LA-KhamNeural", "female": "lo-LA-KhamNeural" },
#   "lithuanian": { "male": "lt-LT-OskarasNeural", "female": "lt-LT-OnaNeural" },
#   "latvian": { "male": "lv-LV-NilsNeural", "female": "lv-LV-ElzaNeural" },
#   "macedonian": { "male": "mk-MK-AleksandarNeural", "female": "mk-MK-MarijaNeural" },
#   "malayalam": { "male": "ml-IN-JeevanNeural", "female": "ml-IN-MadhuriNeural" },
#   "mongolian": { "male": "mn-MN-BataaNeural", "female": "mn-MN-BayarmaaNeural" },
#   "marathi": { "male": "mr-IN-MadhavNeural", "female": "mr-IN-AarohiNeural" },
#   "malay": { "male": "ms-MY-OsmanNeural", "female": "ms-MY-YasminNeural" },
#   "maltese": { "male": "mt-MT-MichaelNeural", "female": "mt-MT-JosephineNeural" },
#   "myanmar": { "male": "my-MM-MaungNeural", "female": "my-MM-MaMaNeural" },
#   "norwegian": { "male": "nb-NO-FinnNeural", "female": "nb-NO-PernilleNeural" },
#   "nepali": { "male": "ne-NP-SujanNeural", "female": "ne-NP-SitaNeural" },
#   "dutch": { "male": "nl-NL-FennaNeural", "female": "nl-NL-LotteNeural" },
#   "oriya": { "male": "or-IN-MadhusmitaNeural", "female": "or-IN-SatyaNeural" },
#   "punjabi": { "male": "pa-IN-AmrinderNeural", "female": "pa-IN-JasleenNeural" },
#   "polish": { "male": "pl-PL-MarekNeural", "female": "pl-PL-ZofiaNeural" },
#   "pashto": { "male": "ps-AF-KamalNeural", "female": "ps-AF-ZarghonaNeural" },
#   "portuguese": { "male": "pt-PT-DuarteNeural", "female": "pt-PT-FernandaNeural" },
#   "romanian": { "male": "ro-RO-AlbertNeural", "female": "ro-RO-AndreeaNeural" },
#   "russian": { "male": "ru-RU-DmitryNeural", "female": "ru-RU-SvetlanaNeural" },
#   "sinhala": { "male": "si-LK-NimaliNeural", "female": "si-LK-NimaliNeural" },
#   "slovak": { "male": "sk-SK-LukasNeural", "female": "sk-SK-ViktoriaNeural" },
#   "slovenian": { "male": "sl-SI-PeterNeural", "female": "sl-SI-MajaNeural" },
#   "somali": { "male": "so-SO-AyaanNeural", "female": "so-SO-NasteexoNeural" },
#   "albanian": { "male": "sq-AL-ErionNeural", "female": "sq-AL-EllaNeural" },
#   "serbian": { "male": "sr-RS-NenadNeural", "female": "sr-RS-SvetlanaNeural" },
#   "sundanese": { "male": "su-ID-DimasNeural", "female": "su-ID-SitiNeural" },
#   "swedish": { "male": "sv-SE-ErikNeural", "female": "sv-SE-SofieNeural" },
#   "swahili": { "male": "sw-KE-AsanteNeural", "female": "sw-KE-ZuriNeural" },
#   "tamil": { "male": "ta-IN-ValluvarNeural", "female": "ta-IN-PallaviNeural" },
#   "telugu": { "male": "te-IN-MohanNeural", "female": "te-IN-ShrutiNeural" },
#   "thai": { "male": "th-TH-PanNeural", "female": "th-TH-SaraNeural" },
#   "tagalog": { "male": "tl-PH-JamesNeural", "female": "tl-PH-JennyNeural" },
#   "turkish": { "male": "tr-TR-EmirNeural", "female": "tr-TR-DeryaNeural" },
#   "uyghur": { "male": "ug-CN-NuriNeural", "female": "ug-CN-NuriNeural" },
#   "ukrainian": { "male": "uk-UA-OstapNeural", "female": "uk-UA-PolinaNeural" },
#   "urdu": { "male": "ur-PK-AsadNeural", "female": "ur-PK-UzmaNeural" },
#   "uzbek": { "male": "uz-UZ-HasanNeural", "female": "uz-UZ-MadinaNeural" },
#   "vietnamese": { "male": "vi-VN-HoangNeural", "female": "vi-VN-NganNeural" },
#   "cantonese": { "male": "yue-HK-HiuGaaiNeural", "female": "yue-HK-HiuMaanNeural" },
#   "chinese": { "male": "zh-CN-YunyangNeural", "female": "zh-CN-XiaoxiaoNeural" }
# }

# %% [raw]
# async def text_to_speech(text: str, voice: str):
#     communicate = edge_tts.Communicate(text=text, voice=voice)
#     audio_data = bytearray()
#
#     async for message in communicate.stream():
#         if message["type"] == "audio":
#             audio_data += message["data"]
#
#     audio_bytes = io.BytesIO(audio_data)
#     display(Audio(audio_bytes.read(), autoplay=True))
#
# async def speak(text: str, lang: str, gender: str):
#     lang = lang.lower()
#     gender = gender.lower()
#
#     if lang not in voice_map:
#         raise ValueError(f"Unsupported language '{lang}'.")
#
#     if gender not in voice_map[lang]:
#         raise ValueError(f"Unsupported gender '{gender}' for language '{lang}'.")
#
#     voice = voice_map[lang][gender]
#
#     await text_to_speech(text, voice)

# %%
from gtts import gTTS
from IPython.display import Audio, display
import io

# %%
def speak(text: str, lang: str):
    tts = gTTS(text=text, lang=lang)
    audio_buffer = io.BytesIO()
    tts.write_to_fp(audio_buffer)
    audio_buffer.seek(0)
    display(Audio(audio_buffer.read(), autoplay=True))
